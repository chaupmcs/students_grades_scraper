# %%
#read the parameters file:
import yaml

with open("parameters.yaml", 'r') as ymlfile:
    parameters = yaml.load(ymlfile)

for ele in parameters.values():
    print(ele)
# Out:
# cs
# An Ninh Mang

# %%
#edit parameters:
parameters['list_to_crawl'] = 'cs'
parameters['mon_hoc'] = 'Data mining'

# mon_hoc = {'Mang Xa Hoi','An Ninh Mang', 'Thuc Tap TN', 'Xu Ly Song Song',
#                    'Phan Tich TKGT', 'Data mining'}
#list_to_crawl: all, cs, cs_ce

with open("parameters.yaml", 'w') as ymlfile:
    yaml.dump(parameters, ymlfile)

# %%
from IPython.display import display, HTML
import CrawlAndParse as code
import pandas as pd

crawl = code.CrawlAndParse()
table = crawl.run()

try:
    # show the dataframe
    pd.set_option("display.max_rows", 999)
    display(HTML(table.to_html(index=False)))
except:
    pass
finally:
    print('chuong trinh ket thuc.')
# Out:
# 	################################################################
# 	#                      ==== CATBUILTS ====                     #
# 	#  ###############     ###################     #############   #
# 	#  #   Ver 2.1   #     ## Crawl + Parse ##     # Jun 14 17 #   #
# 	#  ###############     ###################     #############   #
# 	################################################################
# starting...
# 0%.5%....20%.25%....40%.45%....60%.65%....80%.85%....
# Data mining: crawl xong !
# Loading the result and save to files...
#
# down xong. Xuat file tai: /home/chauuser/KienThuc/store_aao_crawl/MT13KHTN/Data mining
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>STT</th>
#       <th>MSSV</th>
#       <th>HoVaTen</th>
#       <th>Nhom</th>
#       <th>DiemThanhPhan</th>
#       <th>DiemThi</th>
#       <th>DiemTK</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>51300257</td>
# ...
